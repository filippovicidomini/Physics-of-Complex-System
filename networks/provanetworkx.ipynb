# %%
# in this file i'm going to use the pakage networkx to create a graph
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import math

# %%
# create a graph
G = nx.Graph()

# %%
G.add_edges_from([(0,1), (1,2)])

# %%
nx.draw(G, with_labels=True, font_weight='bold')
