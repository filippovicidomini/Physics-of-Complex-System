# %%
# file to plot the entropy s(e) as a funnction of energy

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# load data
kb = 8.617e-5  # eV/K
N = 1000

Np = np.linspace(0, N)

# %%
def entropy(Np, N):
    return kb * (N * np.log(N) - Np * np.log(Np) - (N - Np) * np.log(N - Np))

# %%
max = entropy(N / 2, N)
max_calc = kb * N * np.log(2)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
fig, ax = plt.subplots()
ax.hlines(max, 0, N, label="max entropy")
ax.hlines(max_calc, 0, N, label="max entropy calc", colors="red")
plt.plot(Np, entropy(Np, N))
plt.show()
# Out:
# /var/folders/t0/h2qbh8_90m34ly3lytn0q_tw0000gn/T/ipykernel_76255/934522572.py:2: RuntimeWarning: divide by zero encountered in log
#   return kb * (N * np.log(N) - Np * np.log(Np) - (N - Np) * np.log(N - Np))
# /var/folders/t0/h2qbh8_90m34ly3lytn0q_tw0000gn/T/ipykernel_76255/934522572.py:2: RuntimeWarning: invalid value encountered in multiply
#   return kb * (N * np.log(N) - Np * np.log(Np) - (N - Np) * np.log(N - Np))

# %%
def entropy_E(E, Np):
    return kb * (N * np.log(N) - Np * np.log(Np) - (E / e - Np) * np.log(E / e - Np))


e = 1.602e-19  # J
E = np.linspace(0, 1e-18, 1000)

# %%
#graph the energy as a funtion of N
# E = epsilon *(Np - nm)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')
fig, ax = plt.subplots()
ax.hlines(0, 0, N, label="max entropy")
plt.plot(Np, E)
plt.show()

# %%
eps = 1
E = np.linspace(-eps, eps, 100)
S = kb * (N * np.log(N) - (N / 2 + E / (2 * eps) * np.log(N / 2 + E / (2 * eps)) - (N / 2 - E / (2 * eps)) * np.log(
    N / 2 - E / (2 * eps))))
print(S)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
fig, ax = plt.subplots(figsize=(8, 5))

plt.plot(E, S)
# plot the vairance of the energy

plt.show()
# Out:
# [0.82049124 0.82047955 0.82046786 0.82045617 0.82044449 0.8204328
#  0.82042111 0.82040942 0.82039773 0.82038605 0.82037436 0.82036267
#  0.82035098 0.82033929 0.82032761 0.82031592 0.82030423 0.82029254
#  0.82028085 0.82026916 0.82025748 0.82024579 0.8202341  0.82022241
#  0.82021072 0.82019903 0.82018735 0.82017566 0.82016397 0.82015228
#  0.82014059 0.8201289  0.82011721 0.82010553 0.82009384 0.82008215
#  0.82007046 0.82005877 0.82004708 0.82003539 0.82002371 0.82001202
#  0.82000033 0.81998864 0.81997695 0.81996526 0.81995357 0.81994188
#  0.8199302  0.81991851 0.81990682 0.81989513 0.81988344 0.81987175
#  0.81986006 0.81984837 0.81983668 0.819825   0.81981331 0.81980162
#  0.81978993 0.81977824 0.81976655 0.81975486 0.81974317 0.81973148
#  0.81971979 0.8197081  0.81969642 0.81968473 0.81967304 0.81966135
#  0.81964966 0.81963797 0.81962628 0.81961459 0.8196029  0.81959121
#  0.81957952 0.81956783 0.81955614 0.81954446 0.81953277 0.81952108
#  0.81950939 0.8194977  0.81948601 0.81947432 0.81946263 0.81945094
#  0.81943925 0.81942756 0.81941587 0.81940418 0.81939249 0.8193808
#  0.81936911 0.81935742 0.81934573 0.81933404]

# %%
epsil = np.linspace(1, 2, 10)

for i in epsil:
    E = np.linspace(-i, i, 10)
    S = kb * (N * np.log(N) - (N / 2 + E / (2 * i) * np.log(N / 2 + E / (2 * i)) - (N / 2 - E / (2 * i)) * np.log(
        N / 2 - E / (2 * i))))
    plt.plot(E, S, label=np.round(i,2), linewidth=2, linestyle='--', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
print(epsil)
print(E)

# %%
espi = 1e-6
E = np.linspace(-espi, espi, 1000)
S_E = N * kb * np.log(2 * N) - 0.5 * N * kb * np.log(N ** 2 - E ** 2 / epsi ** 2) - E / (2 * epsi) * kb * np.log(
    ((N + E) / espi) / ((N - E) / espi))
plt.grid(axis='both', which='major', linestyle='--', linewidth=0.5, color='black', alpha=0.5, zorder=0)
plt.plot(E, S_E)
plt.show()
# Out:
# /var/folders/t0/h2qbh8_90m34ly3lytn0q_tw0000gn/T/ipykernel_76255/3387566017.py:3: RuntimeWarning: divide by zero encountered in divide
#   S_E = N * kb * np.log(2 * N) - 0.5 * N * kb * np.log(N ** 2 - E ** 2 / epsi ** 2) - E / (2 * epsi) * kb * np.log(
# /var/folders/t0/h2qbh8_90m34ly3lytn0q_tw0000gn/T/ipykernel_76255/3387566017.py:3: RuntimeWarning: invalid value encountered in log
#   S_E = N * kb * np.log(2 * N) - 0.5 * N * kb * np.log(N ** 2 - E ** 2 / epsi ** 2) - E / (2 * epsi) * kb * np.log(

# %%
espilon = 1e-12
E = np.linspace(-espilon, espilon, 1000)
T = -2*espilon*kb*1/(np.log((espilon * (N+E)/(espilon * (N-E)))))
plt.grid(axis='both', which='major', linestyle='--', linewidth=0.5, color='black', alpha=0.5, zorder=0)
plt.plot(E, T, c='red', marker='o', label='T', zorder=1)
plt.legend()

plt.show()
# Out:
# /var/folders/t0/h2qbh8_90m34ly3lytn0q_tw0000gn/T/ipykernel_76255/695861696.py:3: RuntimeWarning: divide by zero encountered in divide
#   T = -2*espilon*kb*1/(np.log((espilon * (N+E)/(espilon * (N-E)))))
